# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
bp1 = pd.DataFrame({
    "Employee_Name" :  ["Ramesh","Amesh","Mesh","Esh","M","Amit","Raj","Aj"],
    "Salary" : [1000,2000,3000,4000,5000,6000,7000,8000]
})
plt.boxplot(bp1["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e7489a6710>,
#   <matplotlib.lines.Line2D at 0x1e7489a6850>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e7489a6990>,
#   <matplotlib.lines.Line2D at 0x1e7489a6ad0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e7489a65d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e7489a6c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e7489a6d50>],
#  'means': []}

# %%
bp2 = pd.DataFrame({
    "Employee_Name" :  ["Ramesh","Amesh","Mesh","Esh","M","Amit","Raj","Aj","Outlier"],
    "Salary" : [1000,2000,3000,4000,5000,6000,7000,8000,50000]
})
plt.boxplot(bp2["Salary"])
plt.title("Employee Salary")
# Out:
# Text(0.5, 1.0, 'Employee Salary')

# %%
bp3 = pd.read_csv("datasets/daraz_dataset.csv")
plt.boxplot(bp3["TotalAmount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e748876490>,
#   <matplotlib.lines.Line2D at 0x1e748877610>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e748876350>,
#   <matplotlib.lines.Line2D at 0x1e748876e90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e7488765d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e748876fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e748877ed0>],
#  'means': []}

# %%
plt.boxplot(bp3["UnitPrice"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e749c18550>,
#   <matplotlib.lines.Line2D at 0x1e749c18690>],
#  'caps': [<matplotlib.lines.Line2D at 0x1e749c187d0>,
#   <matplotlib.lines.Line2D at 0x1e749c18910>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1e749c18410>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e749c18a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e749c18b90>],
#  'means': []}
