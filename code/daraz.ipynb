# %%
import pandas as pd

# %%
dd = pd.read_csv("datasets/daraz_dataset.csv")
print(dd)
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
# # print(dd.shape)
# print(dd.columns)
print(dd.info())
# print(dd["TotalAmount"].max())
# print(dd["TotalAmount"].min())
# print(dd["TotalAmount"].mean())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          500 non-null    str
#  1   OrderDate        500 non-null    str
#  2   CustomerName     500 non-null    str
#  3   Age              500 non-null    int64
#  4   Gender           500 non-null    str
#  5   District         500 non-null    str
#  6   Category         500 non-null    str
#  7   Product          500 non-null    str
#  8   Quantity         500 non-null    int64
#  9   UnitPrice        500 non-null    int64
#  10  DiscountPercent  500 non-null    int64
#  11  TotalAmount      500 non-null    float64
#  12  PaymentMethod    500 non-null    str
#  13  Rating           500 non-null    int64
#  14  OrderStatus      500 non-null    str
# dtypes: float64(1), int64(5), str(9)
# memory usage: 58.7 KB
# None

# %%
print(dd[["CustomerName","District","TotalAmount"]])
# Out:
#        CustomerName   District  TotalAmount
# 0      Anita Basnet  Nepalgunj     44008.20
# 1      Pooja Basnet    Pokhara     53468.80
# 2      Rohit Basnet   Lalitpur     78290.10
# 3      Pooja Sharma    Chitwan     88175.00
# 4      Ram Adhikari     Dharan      3137.85
# ..              ...        ...          ...
# 495      Sita Thapa  Nepalgunj    115060.80
# 496    Ram Adhikari  Bhaktapur     21686.60
# 497  Nabin Shrestha    Itahari     48890.00
# 498   Gita Shrestha     Dharan     11106.00
# 499  Rohit Adhikari  Bhaktapur     68693.40
#
# [500 rows x 3 columns]

# %%
# # print(dd.iloc[1]) #iloc-->integer location and write index inside big bracket
# # print(dd.iloc[0]) 
# # print(dd.iloc[11]) #11 index ko rows lai dekhayo
# # print(dd.iloc[0:5]) 
# print(dd.iloc[0,2]) #iloc completely indexing ma kam garxa and here 2 is column
# print(dd.iloc[:,2]) # 2 columns ko data dekhaxa
# print(dd.iloc[:,[2,6,8]]) # for multiple columns ko lagi
# print(dd.iloc[-1]) #last data
# print(dd.iloc[0:5,0:3]) #rows and columns
# Out:
#     OrderID   OrderDate  CustomerName
# 0  DZ100001  2026-03-04  Anita Basnet
# 1  DZ100002  2026-01-07  Pooja Basnet
# 2  DZ100003  2026-03-29  Rohit Basnet
# 3  DZ100004  2026-04-28  Pooja Sharma
# 4  DZ100005  2026-03-16  Ram Adhikari

# %%
# # # # print(dd.loc[:,["District","CustomerName"]]) #column name
# # # print(dd.loc[dd["District"]=="Kathmandu"])  #show the customer who buys only from kathmandu district
# # print(dd.loc[dd["TotalAmount"]>30000]) #show the who buys greater than 30k
# # print(dd.loc[(dd["District"] == "Kathmandu") & (dd["PaymentMethod"] == "eSewa")]) #filtering chaining --->kathmandu district bata esewa payment method use gareko
# print(dd.loc[(dd["Category"] == "Electronics") & (dd["Rating"] == 5)])

# %%
#sort is used for price high to low or low to high.. 
print(dd.sort_values("TotalAmount",ascending=False)) #default ma ascending order hunxa ra hamle ascending lai fasle garem vane descending
