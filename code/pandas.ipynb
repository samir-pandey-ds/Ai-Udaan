# %%
import pandas as pd

# %%
result = pd.Series(["japan","usa","nepal"])
print(result)
# Out:
# 0    japan
# 1      usa
# 2    nepal
# dtype: object

# %%
number_series = pd.Series([10,20,30], index=["ek","dui","tin"])
print(number_series["dui"])
# Out:
# 20

# %%
student_data ={
    "name" : ["manish","samir","raju"],
    "age" : [24,21,22],
    "course" : ["ai_udan","mern","reactjs"]
}

student_dataframe = pd.DataFrame(student_data)
print(student_dataframe)
# Out:
#      name  age   course
# 0  manish   24  ai_udan
# 1   samir   21     mern
# 2    raju   22  reactjs

# %%
students_datas =pd.read_csv("datasets/student_data.csv")
print(students_datas)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
dummy_data = pd.read_excel("datasets/dummy.xlsx")
print(dummy_data)
# Out:
#    Population Level Data Sources Available for Use by Service Providers in the Capital Region  \
# 0                                                 NaN
# 1   Purpose: The purpose of this spreadsheet is to...
# 2                         Version Date: Oct 9th, 2025
# 3   Author: Island Health's Population and Public ...
# 4   Contact: For questions, please contact Kirsten...
# ..                                                ...
# 70         Canadian Income Survey (Statistics Canada)
# 71                                BC Cancer Dashboard
# 72   BC Centre on Substance Use Drug Checking Results
# 73   2025 Point in Time Homelessness Count and Survey
# 74                        CRFAIR Research and Reports
#
#                                            Unnamed: 1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# ...

# %%
todos_data =pd.read_json("datasets/todos.json")
print(todos_data)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %%
netflix = pd.read_csv("datasets/netflix_data.csv")
print(netflix)
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(netflix.describe())
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
# print(netflix.head())  #first 5 rowws return
print(netflix.head(2)) #first 2 rowws return
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# print(netflix.tail())  #last 5 rowws return
print(netflix.tail(2))  #last 2 rowws return
# print(netflix.sample(3)) # randomly  3 ota   return
# Out:
#      show_id   type   title      director  \
# 8805   s8806  Movie    Zoom  Peter Hewitt
# 8806   s8807  Movie  Zubaan   Mozez Singh
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
# # print(netflix.shape) #rows(8807) and colums(12) of the dataset
# print(netflix.columns) #dataset ma vayeko column return garxa
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')

# %%
# # print(netflix.dtypes) #dataset ma vako columns ko dataset return garxa
# print(netflix.info()) # shape,columns,dtypes all in one
print(netflix.describe())  #numerical description ,numerical columns xa teslai describe garxa
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000
